# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"CUDA Version: {torch.version.cuda}")

# Note: For faster training, we'll use num_workers=8 and pin_memory=True
# in DataLoaders where applicable. YOLO handles this internally, but if you
# create custom DataLoaders, use these settings for optimal performance.
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 5090
# CUDA Version: 12.8

# %%
import multiprocessing
cores = multiprocessing.cpu_count()
print(f"Number of CPU cores available: {cores}")
# Out:
# Number of CPU cores available: 64

# %%
# !nvidia-smi
# Out:
# Thu Dec 11 00:38:47 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.51.03              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        On  |   00000000:01:00.0 Off |                  N/A |
# |  0%   44C    P8             20W /  575W |       4MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
